# %% [markdown]
# # Nutrition Facts for McDonald's Menu

# %% [markdown]
# ## Importing Necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk
# %matplotlib inline

# %% [markdown]
# ## Reading the Data Set.

# %%
file1 = pd.read_csv('./DataSets/menu.csv')

# %%
file1.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
file1.tail()
# Out:
#                Category                                               Item  \
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# 255  10.1 oz (285 g)       510                150       17.0
# 256  13.4 oz (381 g)       690                200       23.0
# 257   6.7 oz (190 g)       340                100       11.0
# 258  14.2 oz (403 g)       810                290       32.0
# 259   7.1 oz (202 g)       410                150       16.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# ...

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Duplicate Values Checking and removing.

# %%
file1.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Null Values Checking and removing if appropriate.

# %%
file1.isna().sum()
# Out:
# Category                         0
# Item                             0
# Serving Size                     0
# Calories                         0
# Calories from Fat                0
# Total Fat                        0
# Total Fat (% Daily Value)        0
# Saturated Fat                    0
# Saturated Fat (% Daily Value)    0
# Trans Fat                        0
# Cholesterol                      0
# Cholesterol (% Daily Value)      0
# Sodium                           0
# Sodium (% Daily Value)           0
# Carbohydrates                    0
# Carbohydrates (% Daily Value)    0
# Dietary Fiber                    0
# Dietary Fiber (% Daily Value)    0
# Sugars                           0
# Protein                          0
# Vitamin A (% Daily Value)        0
# Vitamin C (% Daily Value)        0
# Calcium (% Daily Value)          0
# Iron (% Daily Value)             0
# dtype: int64

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Analysis on categorical Columns

# %%
file1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
file1.columns
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'Total Fat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
# No of categories in the data set.

print(file1['Category'].nunique())
print()
print(file1['Category'].unique())
# Out:
# 9
#
# ['Breakfast' 'Beef & Pork' 'Chicken & Fish' 'Salads' 'Snacks & Sides'
#  'Desserts' 'Beverages' 'Coffee & Tea' 'Smoothies & Shakes']

# %%
# No of items per each Category

file1.groupby(file1['Category'])['Item'].size()
# Out:
# Category
# Beef & Pork           15
# Beverages             27
# Breakfast             42
# Chicken & Fish        27
# Coffee & Tea          95
# Desserts               7
# Salads                 6
# Smoothies & Shakes    28
# Snacks & Sides        13
# Name: Item, dtype: int64

# %%
# Different Items avaiable in each Category

print(file1.groupby('Category')['Item'].nunique())
print(file1.groupby('Category')['Item'].unique())
# Out:
# Category
# Beef & Pork           15
# Beverages             27
# Breakfast             42
# Chicken & Fish        27
# Coffee & Tea          95
# Desserts               7
# Salads                 6
# Smoothies & Shakes    28
# Snacks & Sides        13
# Name: Item, dtype: int64
# Category
# Beef & Pork           [Big Mac, Quarter Pounder with Cheese, Quarter...
# Beverages             [Coca-Cola Classic (Small), Coca-Cola Classic ...
# Breakfast             [Egg McMuffin, Egg White Delight, Sausage McMu...
# Chicken & Fish        [Premium Crispy Chicken Classic Sandwich, Prem...
# Coffee & Tea          [Iced Tea (Small), Iced Tea (Medium), Iced Tea...
# Desserts              [Baked Apple Pie, Chocolate Chip Cookie, Oatme...
# Salads                [Premium Bacon Ranch Salad (without Chicken), ...
# Smoothies & Shakes    [Blueberry Pomegranate Smoothie (Small), Blueb...
# Snacks & Sides        [Chipotle BBQ Snack Wrap (Crispy Chicken), Chi...
# Name: Item, dtype: object

# %%
sns.countplot(x = 'Category', data = file1, hue = 'Category', palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
# No of unique values in Item

print(file1['Item'].nunique())
# print(file1['Item'].unique())
# Out:
# 260

# %%
# Let's get the numerical data.

numerical_data = file1.select_dtypes(include=['number'])
numerical_data.columns
# Out:
# Index(['Calories', 'Calories from Fat', 'Total Fat',
#        'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %% [markdown]
# ### Let's find the mean value of numerical_columns associated with each category

# %%
groupByData = file1.groupby('Category')
# let's find the mean of each of the numerical value found in each category.

for i in numerical_data.columns:
    print("*"*100)
    mean_values = groupByData[i].mean()
    print("-"*100)
    max_value = groupByData[i].mean().max()
    min_value = groupByData[i].mean().min()
    max_index = groupByData[i].mean().idxmax()
    min_index = groupByData[i].mean().idxmin()
    print(f"{i} :\n{mean_values}")
    print(f"Max Mean {i} : {max_value} ({max_index})")
    print(f"Min Mean {i} : {min_value} ({min_index})")
    print("-"*100)
# Out:
# ****************************************************************************************************
# ----------------------------------------------------------------------------------------------------
# Calories :
# Category
# Beef & Pork           494.000000
# Beverages             113.703704
# Breakfast             526.666667
# Chicken & Fish        552.962963
# Coffee & Tea          283.894737
# Desserts              222.142857
# Salads                270.000000
# Smoothies & Shakes    531.428571
# Snacks & Sides        245.769231
# Name: Calories, dtype: float64
# Max Mean Calories : 552.9629629629629 (Chicken & Fish)
# Min Mean Calories : 113.70370370370371 (Beverages)
# ----------------------------------------------------------------------------------------------------
# ****************************************************************************************************
# ----------------------------------------------------------------------------------------------------
# ...

# %%
sns.barplot(x='Category', y = 'Calories', data = file1, estimator='mean', hue = 'Category')

plt.xticks(rotation = 90)
plt.show()

# %%
sns.displot(x = 'Calories', data = file1, kde = True, rug = True)

# %%
file1['Calories'].mean()
# Out:
# 368.2692307692308

# %%
print(file1['Calories'].max())
print(file1['Calories'].min())
# Out:
# 1880
# 0

# %%
file1.loc[:,'Calories':]
# Out:
#      Calories  Calories from Fat  Total Fat  Total Fat (% Daily Value)  \
# 0         300                120       13.0                         20
# 1         250                 70        8.0                         12
# 2         370                200       23.0                         35
# 3         450                250       28.0                         43
# 4         400                210       23.0                         35
# ..        ...                ...        ...                        ...
# 255       510                150       17.0                         26
# 256       690                200       23.0                         35
# 257       340                100       11.0                         17
# 258       810                290       32.0                         50
# 259       410                150       16.0                         25
#
#      Saturated Fat  Saturated Fat (% Daily Value)  Trans Fat  Cholesterol  \
# ...

# %%
# Whcih item gives max Calories


file1.iloc[file1['Calories'].idxmax(), :] # type: ignore
# Out:
# Category                                       Chicken & Fish
# Item                             Chicken McNuggets (40 piece)
# Serving Size                                  22.8 oz (646 g)
# Calories                                                 1880
# Calories from Fat                                        1060
# Total Fat                                               118.0
# Total Fat (% Daily Value)                                 182
# Saturated Fat                                            20.0
# Saturated Fat (% Daily Value)                             101
# Trans Fat                                                 1.0
# Cholesterol                                               265
# Cholesterol (% Daily Value)                                89
# Sodium                                                   3600
# Sodium (% Daily Value)                                    150
# Carbohydrates                                             118
# ...

# %%
file1[file1['Calories'] == file1['Calories'].max()]
# Out:
#           Category                          Item     Serving Size  Calories  \
# 82  Chicken & Fish  Chicken McNuggets (40 piece)  22.8 oz (646 g)      1880
#
#     Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 82               1060      118.0                        182           20.0
#
#     Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# 82                            101        1.0  ...            118
#
#     Carbohydrates (% Daily Value)  Dietary Fiber  \
# 82                             39              6
#
#     Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 82                             24       1       87                          0
#
#     Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)
# 82                         15                        8                    25
#
# [1 rows x 24 columns]

# %%
for i in numerical_data:
	print(i)
	display(file1[file1[i] == file1[i].max()])
	print("-----------------------------------------------------------")
# Out:
# Calories
#           Category                          Item     Serving Size  Calories  \
# 82  Chicken & Fish  Chicken McNuggets (40 piece)  22.8 oz (646 g)      1880
#
#     Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 82               1060      118.0                        182           20.0
#
#     Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# 82                            101        1.0  ...            118
#
#     Carbohydrates (% Daily Value)  Dietary Fiber  \
# 82                             39              6
#
#     Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 82                             24       1       87                          0
#
#     Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)
# 82                         15                        8                    25
#
# [1 rows x 24 columns]
# -----------------------------------------------------------
# ...

# %%
file1.corr(numeric_only=True)
# Out:
#                                Calories  Calories from Fat  Total Fat  \
# Calories                       1.000000           0.904588   0.904409
# Calories from Fat              0.904588           1.000000   0.999663
# Total Fat                      0.904409           0.999663   1.000000
# Total Fat (% Daily Value)      0.904123           0.999725   0.999765
# Saturated Fat                  0.845564           0.847008   0.846707
# Saturated Fat (% Daily Value)  0.847631           0.849592   0.849293
# Trans Fat                      0.522441           0.433686   0.431453
# Cholesterol                    0.596399           0.682161   0.680547
# Cholesterol (% Daily Value)    0.595208           0.681607   0.680000
# Sodium                         0.712309           0.846624   0.846158
# Sodium (% Daily Value)         0.713415           0.847276   0.846780
# Carbohydrates                  0.781539           0.461672   0.461213
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(data = file1.corr(numeric_only=True), annot = True, )
plt.show()

# %%
sns.pairplot(file1)

# %%
sns.violinplot(y = 'Calories', data =file1, x = 'Category')
plt.xticks(rotation = 90)
plt.show()
